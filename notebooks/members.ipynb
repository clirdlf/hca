# %%
# %pip -q install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

rfn = pd.read_csv('rfn_members-geocoded.csv')
aau = pd.read_csv('aau_members-geocoded.csv')

# %%
df_all = rfn.merge(aau.drop_duplicates(), on=['institution'], how='left', indicator=True)
df_all
# Out:
#     Unnamed: 0.1  Unnamed: 0_x           country_x  \
# 0              0             0             Belgium
# 1              1             1              Benign
# 2              2             2              Benign
# 3              3             3        Burkina Faso
# 4              4             4        Burkina Faso
# 5              5             5            Cambodia
# 6              6             6            Cameroon
# 7              7             7              Canada
# 8              8             8  CanadaBurkina Faso
# 9              9             9         Ivory Coast
# 10            10            10         Ivory Coast
# 11            11            11               Egypt
# 12            12            12              France
# 13            13            13               Haiti
# 14            14            14               Haiti
# 15            15            15           Luxemburg
# 16            16            16          Madagascar
# ...
